# %%
import pandas as pd
df = pd.read_csv('figures/processed_results.csv')
df.query('model == "ether0"').groupby('question_category').agg({'is_correct': 'mean'})
# Out:
#                    is_correct
# question_category
# nmr_elucidation      0.000000
# reaction             0.266667
